# %% [markdown]
# <a href="https://colab.research.google.com/github/SAMUEL24383/Mini-projet/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
note1 = input("Entrer votre note : ")
note2 = input("Entrer votre note : ")
note3 = input("Entrer votre note : ")
resultat = (int(note1) + int(note2) + int(note3)) /3
print("La moyenne de lélève est :", str(resultat) )
# Out:
# Entrer votre note : 15
# Entrer votre note : 16
# Entrer votre note : 19
# La moyenne de lélève est : 16.666666666666668
